# %% [markdown]
# # Python Basics Notebook
# This notebook covers:
# - Writing simple Python scripts
# - Using variables and data types
# - Accepting user input
# - Using operators
# - Writing simple logic using `if` statements

# %% [markdown]
# ## 1. Simple Python Script

# %%
print("Welcome to the Python Basics Session!")
print("This is your first Python script.")

# %% [markdown]
# ## 2. Variables and Data Types

# %%
# Numeric types
age = 40
height = 5.9

# String type
name = "John Doe"

# Boolean type
is_employee = True

print(name, age, height, is_employee)

# %% [markdown]
# ### Task: Store your own details in variables and print them

# %%
# Your code here

# %% [markdown]
# ## 3. Accepting User Input

# %%
user_name = input("Enter your name: ")
print("Hello,", user_name)

# %% [markdown]
# ### Task: Ask for two numbers and print their sum

# %%
# Your code here

# %% [markdown]
# ## 4. Using Operators

# %%
a = 10
b = 3
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponent:", a ** b)

# %% [markdown]
# ### Comparison Operators

# %%
print(a > b)
print(a == b)
print(a != b)

# %% [markdown]
# ### Logical Operators

# %%
x = True
y = False
print(x and y)
print(x or y)
print(not x)

# %% [markdown]
# ### Task: Check if a number is even or odd

# %%
# Your code here

# %% [markdown]
# ## 5. If Statements (Optional)

# %%
age = int(input("Enter your age: "))
if age < 18:
    print("You are a minor.")
elif age <= 60:
    print("You are an adult.")
else:
    print("You are a senior citizen.")

# %% [markdown]
# ### Task: Pass/Fail Checker

# %%
# Your code here
